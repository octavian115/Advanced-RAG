# %%
from langchain_community.document_loaders.json_loader import JSONLoader
from pathlib import Path
from pprint import pp

# %%
file_path = Path("../knowledge-source/apparels.json")
file_path.exists()
# Out:
# True

# %%
def metadata_func(record: dict, metadata: dict) -> dict:
    metadata["product_name"] = record["productName"]
    metadata["category"] = record["category"]
    metadata["price"] = record["price"]

    #delete seq no
    del metadata["seq_num"]

    return metadata

# %%
loader = JSONLoader(
    file_path=file_path.as_posix(),
    jq_schema=".products[]",
    content_key="Description",
    metadata_func=metadata_func
)

# %%
json_docs = loader.load()

# %%
json_docs
# Out:
# [Document(metadata={'source': '/Users/ayush/Documents/rag-projects/Advanced_Rag_Codes/01_document_loaders/knowledge-source/apparels.json', 'product_name': 'PINSTRIPE COAT', 'category': 'Men Cloths', 'price': 4900}, page_content='Oversize-fit coat made of a viscose blend fabric. Notch lapel collar and long sleeves with buttoned cuffs.'),
#  Document(metadata={'source': '/Users/ayush/Documents/rag-projects/Advanced_Rag_Codes/01_document_loaders/knowledge-source/apparels.json', 'product_name': 'OVERSIZED TECHNICAL TRENCH COAT', 'category': 'Men Cloths', 'price': 4900}, page_content='Trench coat made of technical fabric with a velvety finish. Notch lapel collar and long sleeves.'),
#  Document(metadata={'source': '/Users/ayush/Documents/rag-projects/Advanced_Rag_Codes/01_document_loaders/knowledge-source/apparels.json', 'product_name': 'PADDED TECHNICAL PARKA', 'category': 'Perfumes', 'price': 5900}, page_content='Parka made of technical fabric, padded on inside. High neck with a hood and long sleeves with elasticated cuffs.'),
#  Document(metadata={'source': '/Users/ayush/Documents/rag-projects/Advanced_Rag_Codes/01_document_loaders/knowledge-source/apparels.json', 'product_name': 'BOGOSS VIBRANT LEATHER 100 ML / 3.38 OZ', 'category': 'Perfumes', 'price': 1900}, page_content='The first Vibrant Leather for le benjamin with its fruity hint of pineapple that gives it modernity, accompanied by cedar notes, adding a woody touch of rejuvenation.'),
#  Document(metadata={'source': '/Users/ayush/Documents/rag-projects/Advanced_Rag_Codes/01_document_loaders/knowledge-source/apparels.json', 'product_name': 'MULTICOLOURED NYLON BACKPACK', 'category': 'Bags', 'price': 2490}, page_content='Multicoloured backpack. Soft construction. Featuring one main zip pocket and a medium-sized zip pocket on the inside.')]

# %%
for doc in json_docs:
    print(doc.page_content, end="\n\n")
# Out:
# Oversize-fit coat made of a viscose blend fabric. Notch lapel collar and long sleeves with buttoned cuffs.
#
# Trench coat made of technical fabric with a velvety finish. Notch lapel collar and long sleeves.
#
# Parka made of technical fabric, padded on inside. High neck with a hood and long sleeves with elasticated cuffs.
#
# The first Vibrant Leather for le benjamin with its fruity hint of pineapple that gives it modernity, accompanied by cedar notes, adding a woody touch of rejuvenation.
#
# Multicoloured backpack. Soft construction. Featuring one main zip pocket and a medium-sized zip pocket on the inside.

# %%
json_docs[0].metadata
# Out:
# {'source': '/Users/ayush/Documents/rag-projects/Advanced_Rag_Codes/01_document_loaders/knowledge-source/apparels.json',
#  'product_name': 'PINSTRIPE COAT',
#  'category': 'Men Cloths',
#  'price': 4900}

# %%
len(json_docs)
# Out:
# 5
